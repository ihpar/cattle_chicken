# %%
import torchvision
from torchview import draw_graph
from clf_model import SensorClassifier

# %%
model = SensorClassifier(
    input_dim=20,
    num_classes=6
)

# %%
model_graph = draw_graph(model, input_size=(16, 20), device='meta')
model_graph.visual_graph.render(
    filename="figures/clf_model",
    format="pdf",
    cleanup=True
)
# Out:
# 'figures/clf_model.pdf'
